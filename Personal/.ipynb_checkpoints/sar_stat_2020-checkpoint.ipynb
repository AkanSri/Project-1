# %%
import pandas as pd
from pathlib import Path
import seaborn as sns
import hvplot.pandas
# %matplotlib inline

# %%
sar_data_2020= Path("..\FInCen CSV Data\FinCen SAR Stats 2020 (Months).csv")
sar_2020_df= pd.read_csv(sar_data_2020, thousands=',', index_col='Year Month')
sar_2020_df
# Out:
#                      State                                     Industry  \
# Year Month
# 2020 January       Alabama  Casino/Card Club - Tribal Authorized Casino
# 2020 January       Alabama  Casino/Card Club - Tribal Authorized Casino
# 2020 January       Alabama  Casino/Card Club - Tribal Authorized Casino
# 2020 January       Alabama                       Depository Institution
# 2020 January       Alabama                       Depository Institution
# ...                    ...                                          ...
# 2020 December      Wyoming                Money Services Business (MSB)
# 2020 December      Wyoming                                      [Total]
# 2020 December      [Total]                                      [Total]
# 2020 [Total]       [Total]                                      [Total]
# All Years [Total]  [Total]                                      [Total]
#
#                   Suspicious Activity    Count
# Year Month
# 2020 January                    Check        2
# 2020 January        Credit/Debit Card        2
# 2020 January                  [Total]        4
# 2020 January                      ACH       96
# 2020 January              Advance Fee        4
# ...                               ...      ...
# 2020 December                 [Total]       28
# 2020 December                 [Total]      106
# 2020 December                 [Total]   123722
# 2020 [Total]                  [Total]  1375169
# All Years [Total]             [Total]  1375169
#
# [20278 rows x 4 columns]

# %%
sar_2020_df=sar_2020_df.loc[sar_2020_df["Industry"]!="[Total]" ]
sar_2020_df=sar_2020_df.loc[sar_2020_df["Suspicious Activity"]!="[Total]" ]
sar_2020_df=sar_2020_df.loc[sar_2020_df["State"]!="[Total]" ]
sar_2020_df.loc[sar_2020_df.index.str.contains("[Total]") ]
sar_2020_df
# Out:
#                  State                                     Industry  \
# Year Month
# 2020 January   Alabama  Casino/Card Club - Tribal Authorized Casino
# 2020 January   Alabama  Casino/Card Club - Tribal Authorized Casino
# 2020 January   Alabama                       Depository Institution
# 2020 January   Alabama                       Depository Institution
# 2020 January   Alabama                       Depository Institution
# ...                ...                                          ...
# 2020 December  Wyoming                       Depository Institution
# 2020 December  Wyoming                       Depository Institution
# 2020 December  Wyoming                            Insurance Company
# 2020 December  Wyoming                Money Services Business (MSB)
# 2020 December  Wyoming                Money Services Business (MSB)
#
#               Suspicious Activity  Count
# Year Month
# 2020 January                Check      2
# 2020 January    Credit/Debit Card      2
# 2020 January                  ACH     96
# 2020 January          Advance Fee      4
# 2020 January        Business Loan      2
# ...                           ...    ...
# 2020 December  Other Fraud (Type)     13
# 2020 December                Wire     14
# 2020 December                Wire      1
# 2020 December  Other Fraud (Type)     17
# 2020 December                Wire     11
#
# [16343 rows x 4 columns]

# %%
grouped_stats = sar_2020_df[["State", "Count"]].copy()
grouped_stats = grouped_stats.groupby('State').count()
grouped_stats
# Out:
#                  Count
# State
# APO / DPO / FPO     13
# Alabama            271
# Alaska             137
# American Samoa      10
# Arizona            354
# ...                ...
# Virginia           373
# Washington         389
# West Virginia      147
# Wisconsin          286
# Wyoming            131
#
# [61 rows x 1 columns]

# %%
mapped_data = grouped_stats.hvplot.bar(
    rot = 90,
    frame_width = 700, frame_height = 500,
    label = "FinCen Fraud SAR Reporting by State in 2019"
)

mapped_data
# Out:
# :Bars   [State]   (Count)

# %%
sar_2020_df= sar_2020_df.reset_index()
sar_2020_df
# Out:
#           Year Month    State                                     Industry  \
# 0       2020 January  Alabama  Casino/Card Club - Tribal Authorized Casino
# 1       2020 January  Alabama  Casino/Card Club - Tribal Authorized Casino
# 2       2020 January  Alabama                       Depository Institution
# 3       2020 January  Alabama                       Depository Institution
# 4       2020 January  Alabama                       Depository Institution
# ...              ...      ...                                          ...
# 16338  2020 December  Wyoming                       Depository Institution
# 16339  2020 December  Wyoming                       Depository Institution
# 16340  2020 December  Wyoming                            Insurance Company
# 16341  2020 December  Wyoming                Money Services Business (MSB)
# 16342  2020 December  Wyoming                Money Services Business (MSB)
#
#       Suspicious Activity  Count
# 0                   Check      2
# 1       Credit/Debit Card      2
# 2                     ACH     96
# 3             Advance Fee      4
# 4           Business Loan      2
# ...                   ...    ...
# 16338  Other Fraud (Type)     13
# 16339                Wire     14
# 16340                Wire      1
# 16341  Other Fraud (Type)     17
# 16342                Wire     11
#
# [16343 rows x 5 columns]

# %%
sar_2020_df= sar_2020_df.astype({'Count':'int'})
#sar_2020_df = sar_2020_df[['State', 'Count']]
#sar_2020_df = sar_2020_df.sort_values('Count', ascending = False)
mapped_data = sar_2020_df.hvplot.bar(hover_cols = 'Industry',hover=True, color = 'blue', x = 'Year Month', y = 'Count',groupby = 'State', rot=90,frame_width = 1000, frame_height = 500, label = 'FinCen Fraud SAR Reporting by State in 2021')
mapped_data
# Out:
# :DynamicMap   [State]
#    :Bars   [Year Month]   (Count,Industry)

# %%
mapped_data.pie()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30948/1857441191.py in <module>
# ----> 1 mapped_data.pie()
#
# AttributeError: 'DynamicMap' object has no attribute 'pie'
